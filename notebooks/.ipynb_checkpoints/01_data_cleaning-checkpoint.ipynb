# %% [markdown]
# # Capstone Project 1: Liver Disease Prediction
# ---
# ## Data Cleaning
# ### Nils Madsen
# ---

# %%
#import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load csv into dataframe and label columns
raw_df = pd.read_csv('../data/indian_liver_dataset_raw.csv', header=None)
raw_df.columns = ['age', 'sex', 'total bili', 'direct bili', 'ALP', 'ALT', 'AST', 'total protein', 'albumin', 
                  'a-g ratio', 'liver disease']

raw_df.head()
# Out:
#    age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 0   65  Female         0.7          0.1  187   16   18            6.8
# 1   62    Male        10.9          5.5  699   64  100            7.5
# 2   62    Male         7.3          4.1  490   60   68            7.0
# 3   58    Male         1.0          0.4  182   14   20            6.8
# 4   72    Male         3.9          2.0  195   27   59            7.3
#
#    albumin  a-g ratio  liver disease
# 0      3.3       0.90              1
# 1      3.2       0.74              1
# 2      3.3       0.89              1
# 3      3.4       1.00              1
# 4      2.4       0.40              1

# %%
print(raw_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
# age              583 non-null int64
# sex              583 non-null object
# total bili       583 non-null float64
# direct bili      583 non-null float64
# ALP              583 non-null int64
# ALT              583 non-null int64
# AST              583 non-null int64
# total protein    583 non-null float64
# albumin          583 non-null float64
# a-g ratio        579 non-null float64
# liver disease    583 non-null int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB
# None

# %% [markdown]
# ___
# ## Data Types
#
# The data types in the raw data already look clean. There are no issues like numeric variables stored as strings. I will the liver disease column to be a boolean variable, but no other changes need be made.
#
# For performance purposes, the sex column could be converted to categorical type. However, I plan to store the cleaned data as another csv file, so making that conversion here would be premature.
# ___

# %%
# convert the values of liver disease column to readable form
raw_df['liver disease'] = raw_df['liver disease'].map({1: 1, 2: 0})
raw_df['liver disease'] = raw_df['liver disease'].astype('bool')
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
# age              583 non-null int64
# sex              583 non-null object
# total bili       583 non-null float64
# direct bili      583 non-null float64
# ALP              583 non-null int64
# ALT              583 non-null int64
# AST              583 non-null int64
# total protein    583 non-null float64
# albumin          583 non-null float64
# a-g ratio        579 non-null float64
# liver disease    583 non-null bool
# dtypes: bool(1), float64(5), int64(4), object(1)
# memory usage: 46.2+ KB

# %%
# view the 4 rows that have NaN values for albumin-globulin ratio
raw_df.loc[pd.isnull(raw_df['a-g ratio']), :]
# Out:
#      age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 209   45  Female         0.9          0.3  189   23   33            6.6
# 241   51    Male         0.8          0.2  230   24   46            6.5
# 253   35  Female         0.6          0.2  180   12   15            5.2
# 312   27    Male         1.3          0.6  106   25   54            8.5
#
#      albumin  a-g ratio  liver disease
# 209      3.9        NaN           True
# 241      3.1        NaN           True
# 253      2.7        NaN          False
# 312      4.8        NaN          False

# %% [markdown]
# ---
# ## Missing values
#
# Since there are only 4 observations with incomplete information, dropping these observations is unlikely to bias the overall dataset in a meaningful way. However, only one variable is missing from these rows, so dropping the entire row seems like a waste of good data.
#
# Another option is to drop the entire variable. However, this option is usually reserved for cases where a large portion of the field is missing. Also, removing an entire variable might reduce the effectiveness of machine learning.
#
# Given the small number of missing values, and the goal of predicting the presence of liver disease, I believe the best way forward is to fill the missing values by imputing from the mean or median of the population. This should give the machine learning algorithm slightly more data to learn from, while not biasing the data set to a great degree.
# ___

# %%
#investigate the distribution of a-g ratio to determine whether to use mean or median for imputation
print(raw_df['a-g ratio'].describe())
raw_df.boxplot('a-g ratio')
plt.show()
plt.gcf().clear()
# Out:
# count    579.000000
# mean       0.947064
# std        0.319592
# min        0.300000
# 25%        0.700000
# 50%        0.930000
# 75%        1.100000
# max        2.800000
# Name: a-g ratio, dtype: float64

# %% [markdown]
# ___
# There are some outliers in the a-g ratio variable, but the mean and median are very close in value. The difference is likely to be minimal, so I will use the mean for the imputation.
# ___

# %%
# impute missing values
liver_df = raw_df.copy()
liver_df.fillna(liver_df.mean(), inplace=True)
print(liver_df.info())

# check that only the previously NaN rows have been changed
print(raw_df.head(5))
print(liver_df.head(5))
print(raw_df.iloc[[209, 241, 253, 312],:])
print(liver_df.iloc[[209, 241, 253, 312],:])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
# age              583 non-null int64
# sex              583 non-null object
# total bili       583 non-null float64
# direct bili      583 non-null float64
# ALP              583 non-null int64
# ALT              583 non-null int64
# AST              583 non-null int64
# total protein    583 non-null float64
# albumin          583 non-null float64
# a-g ratio        583 non-null float64
# liver disease    583 non-null bool
# dtypes: bool(1), float64(5), int64(4), object(1)
# memory usage: 46.2+ KB
# None
#    age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 0   65  Female         0.7          0.1  187   16   18            6.8
# 1   62    Male        10.9          5.5  699   64  100            7.5
# 2   62    Male         7.3          4.1  490   60   68            7.0
# 3   58    Male         1.0          0.4  182   14   20            6.8
# 4   72    Male         3.9          2.0  195   27   59            7.3
#
#    albumin  a-g ratio  liver disease
# 0      3.3       0.90           True
# 1      3.2       0.74           True
# 2      3.3       0.89           True
# 3      3.4       1.00           True
# 4      2.4       0.40           True
#    age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 0   65  Female         0.7          0.1  187   16   18            6.8
# 1   62    Male        10.9          5.5  699   64  100            7.5
# 2   62    Male         7.3          4.1  490   60   68            7.0
# 3   58    Male         1.0          0.4  182   14   20            6.8
# 4   72    Male         3.9          2.0  195   27   59            7.3
#
#    albumin  a-g ratio  liver disease
# 0      3.3       0.90           True
# 1      3.2       0.74           True
# 2      3.3       0.89           True
# 3      3.4       1.00           True
# 4      2.4       0.40           True
#      age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 209   45  Female         0.9          0.3  189   23   33            6.6
# 241   51    Male         0.8          0.2  230   24   46            6.5
# 253   35  Female         0.6          0.2  180   12   15            5.2
# 312   27    Male         1.3          0.6  106   25   54            8.5
#
#      albumin  a-g ratio  liver disease
# 209      3.9        NaN           True
# 241      3.1        NaN           True
# 253      2.7        NaN          False
# 312      4.8        NaN          False
#      age     sex  total bili  direct bili  ALP  ALT  AST  total protein  \
# 209   45  Female         0.9          0.3  189   23   33            6.6
# 241   51    Male         0.8          0.2  230   24   46            6.5
# 253   35  Female         0.6          0.2  180   12   15            5.2
# 312   27    Male         1.3          0.6  106   25   54            8.5
#
#      albumin  a-g ratio  liver disease
# 209      3.9   0.947064           True
# 241      3.1   0.947064           True
# 253      2.7   0.947064          False
# 312      4.8   0.947064          False

# %%
# check for duplicate rows
liver_df.duplicated().sum()
# Out:
# 13

# %% [markdown]
# ___
# ## Duplicate Rows
#
# There are 13 duplicate rows in the data set. Unfortunately, there is no column giving a unique identifier for each patient, so there is no way to determine whether these rows are actually duplicated, or if they refer to multiple patients who happened to have exactly the same measures along all the variables. Because of this, I will elect to trust the original data set and include the duplicate rows.
# ___

# %%
#check for outliers, and plot distributions
liver_df.boxplot('age', by='liver disease', grid=False)
plt.show()

plt_range = (0, 100)
plt_bins = 10
plt.subplot(1, 2, 1)
plt.hist(liver_df.age[liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('Age - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df.age[liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('Age - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('total bili', by='liver disease', grid=False)
plt.show()

plt_range = (0, 10)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['total bili'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('Total bili - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['total bili'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('Total bili - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('direct bili', by='liver disease', grid=False)
plt.show()

plt_range = (0, 7.5)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['direct bili'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('Direct bili - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['direct bili'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('Direct bili - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('ALP', by='liver disease', grid=False)
plt.show()

plt_range = (0, 1000)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['ALP'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('ALP - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['ALP'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('ALP - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('ALT', by='liver disease', grid=False)
plt.show()

plt_range = (0, 250)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['ALT'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('ALT - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['ALT'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('ALT - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('AST', by='liver disease', grid=False)
plt.show()

plt_range = (0, 1000)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['AST'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('AST - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['AST'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('AST - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('total protein', by='liver disease', grid=False)
plt.show()

plt_range = (3, 10)
plt_bins = 10
plt.subplot(1, 2, 1)
plt.hist(liver_df['total protein'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('Total protein - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['total protein'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('Total protein - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('albumin', by='liver disease', grid=False)
plt.show()

plt_range = (0, 6)
plt_bins = 15
plt.subplot(1, 2, 1)
plt.hist(liver_df['albumin'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('Albumin - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['albumin'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('Albumin - Liver disease')
plt.show()
plt.gcf().clear()

# %%
liver_df.boxplot('a-g ratio', by='liver disease', grid=False)
plt.show()

plt_range = (0, 2)
plt_bins = 10
plt.subplot(1, 2, 1)
plt.hist(liver_df['a-g ratio'][liver_df['liver disease']==False], bins=plt_bins, range=plt_range)
plt.title('A-g ratio - No liver disease')

plt.subplot(1, 2, 2)
plt.hist(liver_df['a-g ratio'][liver_df['liver disease']==True], bins=plt_bins, range=plt_range)
plt.title('A-g ratio - Liver disease')
plt.show()
plt.gcf().clear()

# %% [markdown]
# ___
# ## Outliers
#
# A significant amount of outliers are present in the total bilirubin, direct bilirubin, ALP, AST, and ALT columns. While this might be alarming in other types of data, the presence of outliers in these measures is not surprising, and is in fact expected in data on liver disease. This is because these measures are of molecules that are normally kept at low concentrations in the blood. When the liver becomes damaged, these measures can rise by orders of magnitude, because there is a failure in the body's ability to keep them low. In addition, the scale of the increase in certain markers is used by doctors to predict what kind of liver disease is present. For example, an ALT score in the 100-200 range might indicate alcoholic or fatty liver, while a measure in the thousands could point to viral hepatitis or poisoning.
#
# A lesser amount of outliers are present in total protein, albumin, and a-g ratio. It is not clear what justification could be made for removing them, and the outliers are not dramatically larger or smaller in these fields, as are the outliers for bilirubin and the liver enzymes.
#
# For these reasons, I believe it is best to include all outliers in the data set.
# ___

# %%
# store the cleaned data in a new csv
liver_df.to_csv('../data/indian_liver_dataset_clean.csv')
